# %% [markdown]
# <a href="https://colab.research.google.com/github/WhyFive/Drone_Image_Segmentation_Model/blob/main/Unet_image256_batch8_eporchs30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import numpy as np
import pandas as pd
from PIL import Image
from IPython.display import SVG
import matplotlib.pyplot as plt
# %matplotlib inline
import os, re, sys, random, shutil, cv2

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import applications, optimizers
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.utils import model_to_dot, plot_model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger, LearningRateScheduler, TensorBoard
from tensorflow.keras.layers import Input, Lambda, Activation, Conv2D, MaxPooling2D, BatchNormalization, Add, concatenate, Conv2DTranspose

# %% [markdown]
# # Load Datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1.0 Preprocessing Image

# %% [markdown]
# ## 1.1 Label Segmentics

# %%
import pandas as pd
label_tab = pd.read_csv('/content/drive/MyDrive/drone_dataset/class_dict_seg.csv')
label_tab
# Out:
#            name    r    g    b
# 0     unlabeled    0    0    0
# 1    paved-area  128   64  128
# 2          dirt  130   76    0
# 3         grass    0  102    0
# 4        gravel  112  103   87
# 5         water   28   42  168
# 6         rocks   48   41   30
# 7          pool    0   50   89
# 8    vegetation  107  142   35
# 9          roof   70   70   70
# 10         wall  102  102  156
# 11       window  254  228   12
# 12         door  254  148   12
# 13        fence  190  153  153
# 14   fence-pole  153  153  153
# 15       person  255   22   96
# 16          dog  102   51    0
# 17          car    9  143  150
# 18      bicycle  119   11   32
# 19         tree   51   51    0
# 20    bald-tree  190  250  190
# 21    ar-marker  112  150  146
# 22     obstacle    2  135  115
# 23  conflicting  255    0    0

# %%
import numpy as np
rgb_label = {}
rgb = label_tab[[' r',' g',' b']].values
rgb = rgb.astype('uint8')

for k, v in zip(rgb, label_tab['name']):
  k = tuple(k)
  rgb_label[k] = v

rgb_label
# Out:
# {(0, 0, 0): 'unlabeled',
#  (128, 64, 128): 'paved-area',
#  (130, 76, 0): 'dirt',
#  (0, 102, 0): 'grass',
#  (112, 103, 87): 'gravel',
#  (28, 42, 168): 'water',
#  (48, 41, 30): 'rocks',
#  (0, 50, 89): 'pool',
#  (107, 142, 35): 'vegetation',
#  (70, 70, 70): 'roof',
#  (102, 102, 156): 'wall',
#  (254, 228, 12): 'window',
#  (254, 148, 12): 'door',
#  (190, 153, 153): 'fence',
#  (153, 153, 153): 'fence-pole',
#  (255, 22, 96): 'person',
#  (102, 51, 0): 'dog',
#  (9, 143, 150): 'car',
#  (119, 11, 32): 'bicycle',
#  (51, 51, 0): 'tree',
#  (190, 250, 190): 'bald-tree',
#  (112, 150, 146): 'ar-marker',
#  (2, 135, 115): 'obstacle',
#  (255, 0, 0): 'conflicting'}

# %% [markdown]
# ## 1.2 Load Image

# %%
from pathlib import Path

img_dir = Path("/content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images")
mask_dir = Path("/content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks")

image_fnames = sorted([
    str(fname) for fname in img_dir.glob("*.jpg")
])

mask_fnames = sorted([
    str(fname) for fname in mask_dir.glob("*.png")
])

print(len(image_fnames), len(mask_fnames))

for img_path, mask_path in zip(image_fnames[:10], mask_fnames[:10]):
  print(img_path," | ", mask_path)
# Out:
# 400 400
# /content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/000.jpg  |  /content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks/000.png
# /content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/001.jpg  |  /content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks/001.png
# /content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/002.jpg  |  /content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks/002.png
# /content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/003.jpg  |  /content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks/003.png
# /content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/004.jpg  |  /content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks/004.png
# /content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/005.jpg  |  /content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks/005.png
# /content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/006.jpg  |  /content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks/006.png
# /content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/008.jpg  |  /content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks/008.png
# /content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/011.jpg  |  /content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks/011.png
# /content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/013.jpg  |  /content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks/013.png

# %% [markdown]
# ## 1.3 One Hot Function

# %%
rgb2id = {v:k for k,v in enumerate(rgb_label.keys())}
id2rgb = {k:v for k,v in enumerate(rgb_label.keys())}

name2id = {v:k for k,v in enumerate(rgb_label.values())}
id2name = {k:v for k,v in enumerate(rgb_label.values())}

# %%
id2rgb
# Out:
# {0: (0, 0, 0),
#  1: (128, 64, 128),
#  2: (130, 76, 0),
#  3: (0, 102, 0),
#  4: (112, 103, 87),
#  5: (28, 42, 168),
#  6: (48, 41, 30),
#  7: (0, 50, 89),
#  8: (107, 142, 35),
#  9: (70, 70, 70),
#  10: (102, 102, 156),
#  11: (254, 228, 12),
#  12: (254, 148, 12),
#  13: (190, 153, 153),
#  14: (153, 153, 153),
#  15: (255, 22, 96),
#  16: (102, 51, 0),
#  17: (9, 143, 150),
#  18: (119, 11, 32),
#  19: (51, 51, 0),
#  20: (190, 250, 190),
#  21: (112, 150, 146),
#  22: (2, 135, 115),
#  23: (255, 0, 0)}

# %%
id2name
# Out:
# {0: 'unlabeled',
#  1: 'paved-area',
#  2: 'dirt',
#  3: 'grass',
#  4: 'gravel',
#  5: 'water',
#  6: 'rocks',
#  7: 'pool',
#  8: 'vegetation',
#  9: 'roof',
#  10: 'wall',
#  11: 'window',
#  12: 'door',
#  13: 'fence',
#  14: 'fence-pole',
#  15: 'person',
#  16: 'dog',
#  17: 'car',
#  18: 'bicycle',
#  19: 'tree',
#  20: 'bald-tree',
#  21: 'ar-marker',
#  22: 'obstacle',
#  23: 'conflicting'}

# %%
import numpy as np

def rgb_to_onehot(rgb_image, colormap):
    colormap = colormap.values()
    one_hot_map = []
    for color in colormap:
      class_map = tf.reduce_all(tf.equal(rgb_image, color), axis=-1)
      one_hot_map.append(class_map)
    oneHotMask = tf.cast(tf.stack(one_hot_map, axis=-1), tf.uint32)
    return oneHotMask

def onehot_to_rgb(onehot, colormap = id2rgb):
    '''Function to decode encoded mask labels
        Inputs:
            onehot - one hot encoded image matrix (height x width x num_classes)
            colormap - dictionary of color to label id
        Output: Decoded RGB image (height x width x 3)
    '''
    single_layer = np.argmax(onehot, axis=-1)
    output = np.zeros( onehot.shape[:2]+(3,) )
    for k in colormap.keys():
        output[single_layer==k] = colormap[k]
    return np.uint8(output)

# %% [markdown]
# ## 1.4 Images Augmentation

# %%
import albumentations as A
import tensorflow as tf
import cv2

def augment_image_mask(image, mask):
    # Random horizontal flip
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    # Random vertical flip
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    # Random rotation
    k = tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32)
    image = tf.image.rot90(image, k)
    mask = tf.image.rot90(mask, k)

    return image, mask

# %% [markdown]
# ## 1.5 Images processing

# %%
img_size = 256
batch_size = 8
num_classes = len(rgb_label)
eporchs = 30

def normalize(data):
    data = tf.cast(data, tf.float32)
    data /= 255.0
    return data

def load_image_mask(img_fname, mask_fname):
    image = tf.io.read_file(img_fname)
    image = tf.io.decode_png(image, channels=3)
    image = tf.image.resize(image, (img_size, img_size))
    image = normalize(image)

    mask = tf.io.read_file(mask_fname)
    mask = tf.io.decode_png(mask, channels=3)
    mask = tf.image.resize(mask, (img_size, img_size), method="nearest")

    return image, mask

# %%
def process_path_train(image_path, mask_path):
    image, mask = load_image_mask(image_path, mask_path)
    image, mask = augment_image_mask(image, mask)
    one_hot = rgb_to_onehot(mask, id2rgb)
    return image, one_hot

def process_path(image_path, mask_path):
    image, mask = load_image_mask(image_path, mask_path)
    one_hot = rgb_to_onehot(mask, id2rgb)
    return image, one_hot

# %% [markdown]
# ## 1.6 Split datasets

# %%
dataset = tf.data.Dataset.from_tensor_slices((image_fnames, mask_fnames))
len(dataset)
# Out:
# 400

# %%
train_size = int(len(dataset)*0.7)
val_size = int(len(dataset)*0.2)
test_size = int(len(dataset)*0.1)

print('train: ', train_size, 'val: ', val_size, 'test: ', test_size)
print('total', train_size+val_size+test_size)
# Out:
# train:  280 val:  80 test:  40
# total 400

# %%
train = dataset.take(train_size)
val = dataset.skip(train_size).take(val_size)
test = dataset.skip(train_size).skip(val_size).take(test_size)

# %%
train = train.map(process_path_train,num_parallel_calls=tf.data.AUTOTUNE)
val = val.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
test = test.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)

# %%
train = train.batch(batch_size)
val = val.batch(batch_size)
test = test.batch(batch_size)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import ImageOps


# Extract the image and mask from the TensorFlow pipeline
image, mask = next(iter(train))

# Convert the tensors to numpy arrays
image_np = image.numpy()
mask_np = mask.numpy()

plt.figure(figsize=(20, 10))  # Adjust the size as needed
for i in range(4):
    plt.subplot(2, 4, i + 1)
    plt.imshow(image_np[i])
    plt.title('Image')
    plt.axis('off')

# Display masks
plt.figure(figsize=(20, 10))  # Adjust the size as needed
for i in range(4):
    plt.subplot(2, 4, i + 1)
    plt.imshow(onehot_to_rgb(mask_np[i], id2rgb))
    plt.title('Mask')
    plt.axis('off')

plt.show()

# %%
image.shape, mask.shape
# Out:
# (TensorShape([8, 256, 256, 3]), TensorShape([8, 256, 256, 24]))

# %% [markdown]
# # Build U-net Model

# %%
from tensorflow.keras import layers

def double_conv_block(x, n_filters):
  # First Conv2D
  x = layers.Conv2D(n_filters, 3, padding="same", activation = "relu", kernel_initializer = "he_normal")(x)
  # Second Conv2D
  x = layers.Conv2D(n_filters, 3, padding="same", activation = "relu", kernel_initializer = "he_normal")(x)

  return x

def upsample_block(x, conv_features, n_filters):
  # Upsample
  x = layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
  # Concatenate
  x = layers.concatenate([x, conv_features])
  # Dropout
  x = layers.Dropout(0.3)(x)
  # Double Conv
  x = double_conv_block(x, n_filters)

  return x

# %%
from tensorflow.keras.applications import VGG16

def build_unet_model(vgg_weight_path=None):
  # Input
  input = layers.Input(shape=(img_size, img_size, 3))

  # Load VGG16 model pretrained on ImageNet
  vgg16 = VGG16(include_top=False, weights='imagenet', input_tensor=input if vgg_weight_path is None else None)

  if vgg_weight_path:
      vgg16.load_weights(vgg_weight_path)

  # Set VGG16 layers to non-trainable
  vgg16.trainable = False

  # Encoder: use VGG16 layers
  f1 = vgg16.get_layer("block1_conv2").output
  f2 = vgg16.get_layer("block2_conv2").output
  f3 = vgg16.get_layer("block3_conv3").output
  f4 = vgg16.get_layer("block4_conv3").output
  bottleneck = vgg16.get_layer("block5_conv3").output

  # Decoder: upsample
  # 6 - Upsample
  u6 = upsample_block(bottleneck, f4, 512)
  # 7 - Upsample
  u7 = upsample_block(u6, f3, 256)
  # 8 - Upsample
  u8 = upsample_block(u7, f2, 128)
  # 9 - Upsample
  u9 = upsample_block(u8, f1, 64)

  # Output
  output = layers.Conv2D(num_classes, (3, 3), padding="same", activation="softmax")(u9)

  unet_model = tf.keras.Model(input, output, name="U-Net-VGG16")

  return unet_model

# %%
unet_model = build_unet_model()
unet_model.summary()
# Out:
# Model: "U-Net-VGG16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1 (Conv2D)     │ (None, 256, 256, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2 (Conv2D)     │ (None, 256, 256, 64)   │         36,928 │ block1_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_pool               │ (None, 128, 128, 64)   │              0 │ block1_conv2[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_conv1 (Conv2D)     │ (None, 128, 128, 128)  │         73,856 │ block1_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_conv2 (Conv2D)     │ (None, 128, 128, 128)  │        147,584 │ block2_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_pool               │ (None, 64, 64, 128)    │              0 │ block2_conv2[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_conv1 (Conv2D)     │ (None, 64, 64, 256)    │        295,168 │ block2_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_conv2 (Conv2D)     │ (None, 64, 64, 256)    │        590,080 │ block3_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_conv3 (Conv2D)     │ (None, 64, 64, 256)    │        590,080 │ block3_conv2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_pool               │ (None, 32, 32, 256)    │              0 │ block3_conv3[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_conv1 (Conv2D)     │ (None, 32, 32, 512)    │      1,180,160 │ block3_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_conv2 (Conv2D)     │ (None, 32, 32, 512)    │      2,359,808 │ block4_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_conv3 (Conv2D)     │ (None, 32, 32, 512)    │      2,359,808 │ block4_conv2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_pool               │ (None, 16, 16, 512)    │              0 │ block4_conv3[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_conv1 (Conv2D)     │ (None, 16, 16, 512)    │      2,359,808 │ block4_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_conv2 (Conv2D)     │ (None, 16, 16, 512)    │      2,359,808 │ block5_conv1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_conv3 (Conv2D)     │ (None, 16, 16, 512)    │      2,359,808 │ block5_conv2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 32, 32, 512)    │      2,359,808 │ block5_conv3[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 32, 1024)   │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ block4_conv3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 32, 32, 1024)   │              0 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 32, 32, 512)    │      4,719,104 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 32, 32, 512)    │      2,359,808 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 64, 64, 256)    │      1,179,904 │ conv2d_1[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ block3_conv3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 64, 64, 512)    │              0 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 64, 64, 256)    │      1,179,904 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 128, 128, 128)  │        295,040 │ conv2d_3[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ block2_conv2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 128, 128, 256)  │              0 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 128, 128, 128)  │        295,040 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 128, 128, 128)  │        147,584 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 256, 256, 64)   │         73,792 │ conv2d_5[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ block1_conv2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 256, 256, 128)  │              0 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 256, 256, 64)   │         73,792 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 256, 256, 64)   │         36,928 │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 256, 256, 24)   │         13,848 │ conv2d_7[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 28,039,320 (106.96 MB)
#  Trainable params: 13,324,632 (50.83 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
plot_model(unet_model, to_file='vgg16_unet_plot.png', show_shapes=True, show_layer_names=True, expand_nested=True)

# %% [markdown]
# # 4.0 Training Model

# %%
from tensorflow.keras.metrics import OneHotIoU, OneHotMeanIoU
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

num_classes = 24
target_class_ids = list(range(num_classes))

one_hot_iou = OneHotIoU(
    num_classes=num_classes,
    target_class_ids=target_class_ids,
    name='one_hot_iou'
)

unet_model.compile(
    optimizer=Adam(learning_rate = 0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy',one_hot_iou]
)

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, CSVLogger

earlystop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    filepath = 'vgg16_unet_model.keras',
    save_best_only = True,
#     save_weights_only = False,
    monitor = 'val_loss',
    mode = 'auto',
    verbose = 1
)

"""
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.01 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.001, 20)

lr_scheduler = LearningRateScheduler(
    exponential_decay_fn,
    verbose=1
)
"""

csv_logger = CSVLogger('Unet_training_log.csv', append=True)

callbacks = [earlystop, csv_logger, checkpoint]

# %%
hist = unet_model.fit(train, epochs=eporchs, validation_data=val, verbose=1, callbacks=callbacks)
# Out:
# Epoch 1/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.2817 - loss: 4.3987 - one_hot_iou: 0.0269
# Epoch 1: val_loss improved from inf to 1.67555, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 65s 837ms/step - accuracy: 0.2845 - loss: 4.3527 - one_hot_iou: 0.0272 - val_accuracy: 0.5701 - val_loss: 1.6756 - val_one_hot_iou: 0.0551
# Epoch 2/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.5054 - loss: 1.8052 - one_hot_iou: 0.0494
# Epoch 2: val_loss improved from 1.67555 to 1.49061, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 687ms/step - accuracy: 0.5055 - loss: 1.8039 - one_hot_iou: 0.0495 - val_accuracy: 0.5824 - val_loss: 1.4906 - val_one_hot_iou: 0.0622
# Epoch 3/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.5218 - loss: 1.6542 - one_hot_iou: 0.0596
# Epoch 3: val_loss improved from 1.49061 to 1.36839, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 693ms/step - accuracy: 0.5221 - loss: 1.6528 - one_hot_iou: 0.0598 - val_accuracy: 0.6119 - val_loss: 1.3684 - val_one_hot_iou: 0.0794
# Epoch 4/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.5674 - loss: 1.4998 - one_hot_iou: 0.0788
# Epoch 4: val_loss improved from 1.36839 to 1.33048, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 691ms/step - accuracy: 0.5675 - loss: 1.4991 - one_hot_iou: 0.0789 - val_accuracy: 0.6263 - val_loss: 1.3305 - val_one_hot_iou: 0.0911
# Epoch 5/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.5916 - loss: 1.4251 - one_hot_iou: 0.0886
# Epoch 5: val_loss improved from 1.33048 to 1.24024, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 682ms/step - accuracy: 0.5917 - loss: 1.4245 - one_hot_iou: 0.0887 - val_accuracy: 0.6531 - val_loss: 1.2402 - val_one_hot_iou: 0.0983
# Epoch 6/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.6005 - loss: 1.3884 - one_hot_iou: 0.0926
# Epoch 6: val_loss improved from 1.24024 to 1.15604, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 693ms/step - accuracy: 0.6007 - loss: 1.3875 - one_hot_iou: 0.0927 - val_accuracy: 0.6663 - val_loss: 1.1560 - val_one_hot_iou: 0.1024
# Epoch 7/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.6169 - loss: 1.3059 - one_hot_iou: 0.0985
# Epoch 7: val_loss improved from 1.15604 to 1.13928, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 689ms/step - accuracy: 0.6168 - loss: 1.3058 - one_hot_iou: 0.0986 - val_accuracy: 0.6643 - val_loss: 1.1393 - val_one_hot_iou: 0.1058
# Epoch 8/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.6239 - loss: 1.2733 - one_hot_iou: 0.1023
# Epoch 8: val_loss improved from 1.13928 to 1.12205, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 707ms/step - accuracy: 0.6238 - loss: 1.2734 - one_hot_iou: 0.1024 - val_accuracy: 0.6429 - val_loss: 1.1221 - val_one_hot_iou: 0.0895
# Epoch 9/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.6007 - loss: 1.2876 - one_hot_iou: 0.0912
# Epoch 9: val_loss improved from 1.12205 to 1.08759, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 686ms/step - accuracy: 0.6010 - loss: 1.2873 - one_hot_iou: 0.0915 - val_accuracy: 0.6820 - val_loss: 1.0876 - val_one_hot_iou: 0.1112
# Epoch 10/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.6246 - loss: 1.2557 - one_hot_iou: 0.1043
# Epoch 10: val_loss improved from 1.08759 to 1.02290, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 697ms/step - accuracy: 0.6248 - loss: 1.2548 - one_hot_iou: 0.1045 - val_accuracy: 0.6926 - val_loss: 1.0229 - val_one_hot_iou: 0.1231
# Epoch 11/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.6443 - loss: 1.1745 - one_hot_iou: 0.1153
# Epoch 11: val_loss improved from 1.02290 to 1.02131, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 703ms/step - accuracy: 0.6442 - loss: 1.1747 - one_hot_iou: 0.1154 - val_accuracy: 0.6970 - val_loss: 1.0213 - val_one_hot_iou: 0.1297
# Epoch 12/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.6381 - loss: 1.1947 - one_hot_iou: 0.1149
# Epoch 12: val_loss improved from 1.02131 to 1.00091, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 685ms/step - accuracy: 0.6380 - loss: 1.1946 - one_hot_iou: 0.1150 - val_accuracy: 0.7021 - val_loss: 1.0009 - val_one_hot_iou: 0.1355
# Epoch 13/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.6493 - loss: 1.1546 - one_hot_iou: 0.1227
# Epoch 13: val_loss improved from 1.00091 to 0.99287, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 693ms/step - accuracy: 0.6492 - loss: 1.1548 - one_hot_iou: 0.1228 - val_accuracy: 0.7006 - val_loss: 0.9929 - val_one_hot_iou: 0.1401
# Epoch 14/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.6585 - loss: 1.1288 - one_hot_iou: 0.1328
# Epoch 14: val_loss improved from 0.99287 to 0.94298, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 686ms/step - accuracy: 0.6586 - loss: 1.1284 - one_hot_iou: 0.1330 - val_accuracy: 0.7165 - val_loss: 0.9430 - val_one_hot_iou: 0.1519
# Epoch 15/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.6686 - loss: 1.0816 - one_hot_iou: 0.1458
# Epoch 15: val_loss improved from 0.94298 to 0.93034, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 687ms/step - accuracy: 0.6686 - loss: 1.0818 - one_hot_iou: 0.1459 - val_accuracy: 0.7165 - val_loss: 0.9303 - val_one_hot_iou: 0.1599
# Epoch 16/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.6686 - loss: 1.0858 - one_hot_iou: 0.1485
# Epoch 16: val_loss improved from 0.93034 to 0.90875, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 685ms/step - accuracy: 0.6687 - loss: 1.0857 - one_hot_iou: 0.1486 - val_accuracy: 0.7249 - val_loss: 0.9087 - val_one_hot_iou: 0.1663
# Epoch 17/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.6767 - loss: 1.0530 - one_hot_iou: 0.1588
# Epoch 17: val_loss improved from 0.90875 to 0.89374, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 696ms/step - accuracy: 0.6767 - loss: 1.0531 - one_hot_iou: 0.1589 - val_accuracy: 0.7264 - val_loss: 0.8937 - val_one_hot_iou: 0.1736
# Epoch 18/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.6828 - loss: 1.0332 - one_hot_iou: 0.1644
# Epoch 18: val_loss improved from 0.89374 to 0.88185, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 686ms/step - accuracy: 0.6829 - loss: 1.0331 - one_hot_iou: 0.1645 - val_accuracy: 0.7307 - val_loss: 0.8818 - val_one_hot_iou: 0.1845
# Epoch 19/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.6895 - loss: 1.0103 - one_hot_iou: 0.1783
# Epoch 19: val_loss improved from 0.88185 to 0.87757, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 699ms/step - accuracy: 0.6895 - loss: 1.0104 - one_hot_iou: 0.1784 - val_accuracy: 0.7304 - val_loss: 0.8776 - val_one_hot_iou: 0.1935
# Epoch 20/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.6902 - loss: 1.0069 - one_hot_iou: 0.1844
# Epoch 20: val_loss improved from 0.87757 to 0.84121, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 691ms/step - accuracy: 0.6903 - loss: 1.0068 - one_hot_iou: 0.1845 - val_accuracy: 0.7412 - val_loss: 0.8412 - val_one_hot_iou: 0.2027
# Epoch 21/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.6955 - loss: 0.9866 - one_hot_iou: 0.1899
# Epoch 21: val_loss improved from 0.84121 to 0.82646, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 701ms/step - accuracy: 0.6955 - loss: 0.9866 - one_hot_iou: 0.1900 - val_accuracy: 0.7450 - val_loss: 0.8265 - val_one_hot_iou: 0.2130
# Epoch 22/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7010 - loss: 0.9628 - one_hot_iou: 0.1998
# Epoch 22: val_loss improved from 0.82646 to 0.80816, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 699ms/step - accuracy: 0.7011 - loss: 0.9628 - one_hot_iou: 0.1999 - val_accuracy: 0.7497 - val_loss: 0.8082 - val_one_hot_iou: 0.2190
# Epoch 23/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7005 - loss: 0.9590 - one_hot_iou: 0.2046
# Epoch 23: val_loss did not improve from 0.80816
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 661ms/step - accuracy: 0.7005 - loss: 0.9592 - one_hot_iou: 0.2047 - val_accuracy: 0.7486 - val_loss: 0.8129 - val_one_hot_iou: 0.2200
# Epoch 24/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.7032 - loss: 0.9498 - one_hot_iou: 0.2059
# Epoch 24: val_loss improved from 0.80816 to 0.79891, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 692ms/step - accuracy: 0.7033 - loss: 0.9498 - one_hot_iou: 0.2060 - val_accuracy: 0.7508 - val_loss: 0.7989 - val_one_hot_iou: 0.2293
# Epoch 25/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.7072 - loss: 0.9333 - one_hot_iou: 0.2113
# Epoch 25: val_loss improved from 0.79891 to 0.79420, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 687ms/step - accuracy: 0.7072 - loss: 0.9334 - one_hot_iou: 0.2114 - val_accuracy: 0.7535 - val_loss: 0.7942 - val_one_hot_iou: 0.2270
# Epoch 26/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.7117 - loss: 0.9186 - one_hot_iou: 0.2134
# Epoch 26: val_loss improved from 0.79420 to 0.77135, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 697ms/step - accuracy: 0.7117 - loss: 0.9185 - one_hot_iou: 0.2135 - val_accuracy: 0.7573 - val_loss: 0.7713 - val_one_hot_iou: 0.2301
# Epoch 27/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7162 - loss: 0.8997 - one_hot_iou: 0.2215
# Epoch 27: val_loss improved from 0.77135 to 0.75997, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 686ms/step - accuracy: 0.7162 - loss: 0.8997 - one_hot_iou: 0.2216 - val_accuracy: 0.7627 - val_loss: 0.7600 - val_one_hot_iou: 0.2345
# Epoch 28/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.7177 - loss: 0.8950 - one_hot_iou: 0.2232
# Epoch 28: val_loss did not improve from 0.75997
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 660ms/step - accuracy: 0.7177 - loss: 0.8951 - one_hot_iou: 0.2233 - val_accuracy: 0.7608 - val_loss: 0.7682 - val_one_hot_iou: 0.2255
# Epoch 29/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.7133 - loss: 0.9114 - one_hot_iou: 0.2175
# Epoch 29: val_loss improved from 0.75997 to 0.75233, saving model to vgg16_unet_model.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 25s 693ms/step - accuracy: 0.7134 - loss: 0.9113 - one_hot_iou: 0.2177 - val_accuracy: 0.7669 - val_loss: 0.7523 - val_one_hot_iou: 0.2401
# Epoch 30/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.7227 - loss: 0.8786 - one_hot_iou: 0.2318
# Epoch 30: val_loss did not improve from 0.75233
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 24s 653ms/step - accuracy: 0.7227 - loss: 0.8787 - one_hot_iou: 0.2320 - val_accuracy: 0.7639 - val_loss: 0.7562 - val_one_hot_iou: 0.2374
# Restoring model weights from the end of the best epoch: 29.

# %%
# !pip install numba

from numba import cuda
device = cuda.get_current_device()
device.reset()
# Out:
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba) (0.43.0)
# Requirement already satisfied: numpy<2.1,>=1.22 in /usr/local/lib/python3.10/dist-packages (from numba) (1.26.4)

# %% [markdown]
# # 5.0 Evaluation

# %%
evaluation = unet_model.evaluate(test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 928ms/step - accuracy: 0.7364 - loss: 0.8476 - one_hot_iou: 0.2323

# %%
img = cv2.imread('/content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/000.jpg')
resize = tf.image.resize(img, (img_size,img_size))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = unet_model.predict(np.expand_dims(resize/255,0))
from PIL import ImageOps
mask = np.argmax(yhat, axis=-1)
mask = np.squeeze(mask) # Remove the extra dimension
# Add a channel dimension to the mask
mask = np.expand_dims(mask, axis=-1)
img = ImageOps.autocontrast(keras.utils.array_to_img(mask))

display(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# <PIL.Image.Image image mode=L size=256x256>

# %%
def onehot_to_rgb(mask, colormap):
    '''Function to decode encoded mask labels
        Inputs:
            mask - mask image matrix (height x width x 1) with class labels
            colormap - dictionary of label id to color
        Output: Decoded RGB image (height x width x 3)
    '''
    height, width, _ = mask.shape
    output = np.zeros((height, width, 3), dtype=np.uint8)

    for label, color in colormap.items():
        output[mask[:, :, 0] == label] = color

    return output

# %%
plt.figure(figsize=(16, 8))  # Adjust the size as needed
plt.imshow(onehot_to_rgb(mask, id2rgb))
plt.title('Mask')
plt.axis('off')

plt.show()

# %%
img = cv2.imread('/content/drive/MyDrive/drone_dataset/dataset/semantic_drone_dataset/original_images/000.jpg')
mask = cv2.imread('/content/drive/MyDrive/drone_dataset/RGB_color_image_masks/RGB_color_image_masks/000.png')

img = tf.image.resize(img, (img_size, img_size))
mask = tf.image.resize(mask, (img_size, img_size))

# Predict the mask using the UNet model
yhat = unet_model.predict(np.expand_dims(img/255, 0))
pri_mask = np.argmax(yhat, axis=-1)
pri_mask = np.squeeze(pri_mask)
pri_mask = np.expand_dims(pri_mask, axis=-1)

# Convert predicted mask to RGB
rgb_mask = onehot_to_rgb(pri_mask, id2rgb)

# Overlay the mask onto the original image
alpha = 0.5  # Transparency factor
overlay = cv2.addWeighted(img.numpy().astype(np.uint8), 1 - alpha, rgb_mask, alpha, 0)

# Display the original image, the original mask, the predicted mask, and the overlay
plt.figure(figsize=(16, 8))

plt.subplot(1, 4, 1)
plt.imshow(img.numpy().astype(int))
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 4, 2)
plt.imshow(mask.numpy().astype(int))
plt.title('Original Mask')
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(rgb_mask)
plt.title('Predicted Mask')
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(overlay)
plt.title('Overlay')
plt.axis('off')

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
